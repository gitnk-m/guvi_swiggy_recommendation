# %%
# Step 1:
# Import libraries
import pandas as pd
import pickle
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
import plotly.express as px

# %%
# Step 2:
# loading the dataset
df = pd.read_csv('dataset/swiggy.csv')

# %%
# Step 3:
# Row with name : NA are dropped because important feature like rating, rating_count, cost, cuisine, lic_no is also NA
df = df.dropna(subset=['name'])

# %%
# Step 4:
# Converting cost to float
df["cost"] = df["cost"].replace('₹ ', "", regex=True).astype(float)

# %%
df.columns
# Out:
# Index(['id', 'name', 'city', 'rating', 'rating_count', 'cost', 'cuisine',
#        'lic_no', 'link', 'address', 'menu'],
#       dtype='object')

# %%
# Step 5:
# Filling missing values in cost and cuisine columns
for col in ["cost", "cuisine"]:
     default_value = 0 if col == "cost" else "Unknown"
     df[col] = (
          df.groupby('name')[col]
          .transform(lambda x: x.fillna(method='ffill').fillna(method='bfill'))
          .fillna(default_value)
          )
# Out:
# C:\Users\nirma\AppData\Local\Temp\ipykernel_15332\4040083446.py:7: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   .transform(lambda x: x.fillna(method='ffill').fillna(method='bfill'))
# C:\Users\nirma\AppData\Local\Temp\ipykernel_15332\4040083446.py:7: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   .transform(lambda x: x.fillna(method='ffill').fillna(method='bfill'))
# C:\Users\nirma\AppData\Local\Temp\ipykernel_15332\4040083446.py:7: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   .transform(lambda x: x.fillna(method='ffill').fillna(method='bfill'))

# %%
# Step 6:
# Converting rating to float
df["rating"]=df["rating"].replace('--',0).astype(float)

# %%
df_backup = df.copy()

# %%
df=df_backup.copy()

# %%
# Step 7:
# Splitting city into area and main city
df[["area", "city_main"]] = df["city"].str.rsplit(',', n=1, expand=True)

# df["city_main"] = df["city"].astype(str).str.split(',').str[1].str.strip()

# cleaning area and city_main columns
df["area"] = df["area"].str.strip()

df["city_main"] = df["city_main"].str.strip()
# Filling missing values in city_main column
df['city_main'].fillna("Other", inplace=True)
# Out:
# C:\Users\nirma\AppData\Local\Temp\ipykernel_15332\300690525.py:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['city_main'].fillna("Other", inplace=True)

# %%
location = {}
for index, row in df.iterrows():
    city = row['city_main'].lower()
    area = row['area'].lower()
    if city not in location:
        location[city] = []
    if area not in location[city]:
        location[city].append(area)

location
pickle.dump(location, open('pickles/city_area.pkl', 'wb'))

# %%
# step 8:
df.drop(columns=['city'], inplace=True)

# %%
# Step 9:
# splitting cuisine into cuisine_1 and cuisine_2
# df[["cuisine_1", "cuisine_2"]] = df["cuisine"].str.split(',', n=1, expand=True)
df[["cuisine_1", "cuisine_2"]] = df["cuisine"].str.split(',', n=1, expand=True).apply(lambda c: c.str.strip())

# %%
# cleaning cuisine_1 and cuisine_2 columns
# cuisine_types = df["cuisine_1"].unique().tolist()+ df["cuisine_2"].unique().tolist()
cuisine_types = list(set(df["cuisine_1"].dropna()).union(df["cuisine_2"].dropna()))
# pd.DataFrame(cuisine_types, columns=["cuisine_type"]).to_csv('dataset/cuisine_types.csv', index=False)

# %%
remove_cuisine = ["8:15 To 11:30 Pm","Attractive Combos Available","Code valid on bill over Rs.99","Combo","Default","Discount offer from Garden Cafe Express Kankurgachi","Free Delivery ! Limited Stocks!","Grocery products","MAX 2 Combos per Order!","Meat","Popular Brand Store","Special Discount from (Hotel Swagath)","SVANidhi Street Food Vendor","Use Code JUMBO30 to avail", "Use code XPRESS121 to avail.","Unknown"]
for cuisine in ["cuisine_1", "cuisine_2"]:
     df[cuisine] = df[cuisine].replace(remove_cuisine, "Other")
     df[cuisine] = df[cuisine].replace("Bakery products", "Bakery")
     df[cuisine] = df[cuisine].replace("BEVERAGE", "Beverages")
     df[cuisine] = df[cuisine].replace("Biryani - Shivaji Military Hotel", "Biryani")

# %%
pickle.dump(df, open('pickles/processed_df.pkl', 'wb'))

# %%
cuisine_types = list(set(df["cuisine_1"].dropna()).union(df["cuisine_2"].dropna()))
pickle.dump(cuisine_types, open('pickles/cuisines.pkl', 'wb'))
# len(cuisine_types)

# %%
# Step 10:
# Enconding cuisine_1 and cuisine_2 columns using OneHotEncoder and saving it as pickle file
oneHot_encoder_cuisine = OneHotEncoder(sparse_output=False, handle_unknown='ignore')
encode_oneHot_cuisine = oneHot_encoder_cuisine.fit_transform(df[["cuisine_1", "cuisine_2"]]) 
pickle.dump(oneHot_encoder_cuisine, open('pickles/oneHot_cuisine.pkl', 'wb'))
encoded_df_oneHot_cuisine = pd.DataFrame(encode_oneHot_cuisine, columns=oneHot_encoder_cuisine.get_feature_names_out(['cuisine_1', 'cuisine_2']))
df = pd.concat([df.reset_index(drop=True), encoded_df_oneHot_cuisine.reset_index(drop=True)], axis=1)
df.drop(columns=['cuisine_1', 'cuisine_2', 'cuisine'], inplace=True)

# %%
# Step 11:
# Enconding city_main column using OneHotEncoder and saving it as pickle file
oneHot_encoder_city = OneHotEncoder(sparse_output=False, handle_unknown='ignore')
encode_oneHot_city = oneHot_encoder_city.fit_transform(df[['city_main']])
pickle.dump(oneHot_encoder_city, open('pickles/oneHot_city.pkl', 'wb'))
encoded_df_oneHot_city = pd.DataFrame(encode_oneHot_city, columns=oneHot_encoder_city.get_feature_names_out(['city_main']))
df = pd.concat([df.reset_index(drop=True), encoded_df_oneHot_city.reset_index(drop=True)], axis=1)
df.drop(columns=['city_main'], inplace=True)

# %%
# Step 12:
area_to_oneHot = False  # Set to False to use LabelEncoder instead of OneHotEncoder
if area_to_oneHot:
    # Encoding area column using OneHotEncoder and saving it as pickle file
    oneHot_encoder_area = OneHotEncoder(sparse_output=False, handle_unknown='ignore')
    encode_oneHot_area = oneHot_encoder_area.fit_transform(df[['area']])
    pickle.dump(oneHot_encoder_area, open('pickles/oneHot_area.pkl', 'wb'))
    encoded_df_oneHot_area = pd.DataFrame(encode_oneHot_area, columns=oneHot_encoder_area.get_feature_names_out(['area']))
    df = pd.concat([df.reset_index(drop=True), encoded_df_oneHot_area.reset_index(drop=True)], axis=1)
    df.drop(columns=['area'], inplace=True)
else:
    print(df["area"])
    # Encoding area column using LabelEncoder and saving it as pickle file
    label_encoder_area = LabelEncoder()
    df["area"]= label_encoder_area.fit_transform(df['area'])
    pickle.dump(label_encoder_area, open('pickles/label_area.pkl', 'wb'))
# Out:
# 0           Abohar
# 1           Abohar
# 2           Abohar
# 3           Abohar
# 4           Abohar
#             ...
# 148450    Yavatmal
# 148451    Yavatmal
# 148452    Yavatmal
# 148453    Yavatmal
# 148454    Yavatmal
# Name: area, Length: 148455, dtype: object

# %%
# Step 13:
# Encoding rating_count column using LabelEncoder and saving it as pickle file
pickle.dump(df["rating_count"], open('pickles/rating_counts.pkl', 'wb'))
label_encoder_rating_count = LabelEncoder()
df["rating_count"]=label_encoder_rating_count.fit_transform(df["rating_count"])
pickle.dump(label_encoder_rating_count, open('pickles/encoder_rating_count.pkl', 'wb'))

# %%
# Step 14:
# Drop lic_no, address, menu and link columns as they are not impactfull for analysis
df.drop(columns=['name','lic_no', 'address', 'menu', 'link'], inplace=True)

# %%
# Step 15:
# index id
df.set_index('id', inplace=True)

# %%
# Step 16:
# clustering with optimal number of clusters
from sklearn.cluster import KMeans
best_k = 6  # From elbow graph
model = KMeans(n_clusters=best_k).fit(df)
df['cluster'] = model.predict(df)

# pickle.dump(df, open('pickles/encoded_df.pkl', 'wb'))
pickle.dump(model, open('pickles/kmeans_model.pkl', 'wb'))

# %%
df.reset_index(inplace=True)
df.columns
# Out:
# (0         567335
#  1         531342
#  2         158203
#  3         187912
#  4         543530
#             ...
#  148450    553122
#  148451    562647
#  148452    559435
#  148453    418989
#  148454    447770
#  Name: id, Length: 148455, dtype: int64,
#  0         2
#  1         2
#  2         2
#  3         2
#  4         2
#           ..
#  148450    5
#  148451    5
#  148452    5
#  148453    5
#  148454    5
#  Name: cluster, Length: 148455, dtype: int32)

# %%
####### Recommendation System Starts#######

# %%
user_input = {
    "rating": 3.0,
    "rating_count": "50+ ratings",
    "cost": 250,
    "area": "Adyar",
    "cuisine_1": "Unknown",
    "cuisine_2": "Unknown",
    "city_main": "Chennai"
}
user_df = pd.DataFrame([user_input])

# %%
import numpy as np
# -------------------------
# 2. Encode numeric + label encoded values
# -------------------------
enc_rating = np.array([[user_df['rating'].iloc[0]]])
enc_cost = np.array([[user_df['cost'].iloc[0]]])
enc_rating_count = label_encoder_rating_count.transform(
    user_df['rating_count']
).reshape(1, -1)
enc_area = label_encoder_area.transform(
    user_df['area']
).reshape(1, -1)

# %%
# -------------------------
# 3. OneHot encodings
# -------------------------
enc_cuisine = oneHot_encoder_cuisine.transform(
    user_df[['cuisine_1', 'cuisine_2']]
)
enc_city = oneHot_encoder_city.transform(
    user_df[['city_main']]
)

# %%
# -------------------------
# 4. Build FINAL VECTOR (Exact feature order used in training)
# -------------------------
final_vector = np.hstack([
    enc_rating,         # feature_rating
    enc_rating_count,   # feature_rating_count
    enc_cost,           # feature_cost
    enc_area,           # feature_area
    enc_cuisine,        # feature_cuisine_*
    enc_city            # feature_city_*
])

# %%
# -------------------------
# 5. Predict Cluster
# -------------------------
cluster = model.predict(final_vector)[0]
cluster_df = df[df['cluster'] == cluster].copy()
# Out:
# d:\Learn\Guvi\DS\project\Swiggy\swiggy_env\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but KMeans was fitted with feature names
#   warnings.warn(

# %%
cluster_vector = cluster_df.drop(columns=['cluster']).values

# %%
from sklearn.metrics.pairwise import cosine_similarity
sim_scores = cosine_similarity(final_vector, cluster_vector)[0]
cluster_df["similarity_score"] = sim_scores

# %%
cluster_df.sort_values(by='similarity_score', ascending=False ).head(10)
# Out:
#         rating  rating_count   cost  area  cuisine_1_8:15 To 11:30 Pm  \
# id
# 10540      4.1             5  300.0     6                         0.0
# 279404     3.8             4  250.0     6                         0.0
# 234933     4.2             5  300.0     6                         0.0
# 30150      4.3             5  300.0     6                         0.0
# 231590     4.3             5  300.0     6                         0.0
# 56318      4.3             5  300.0     6                         0.0
# 146253     3.8             4  300.0     6                         0.0
# 480768     4.0             4  250.0     6                         0.0
# 503857     4.5             5  300.0     6                         0.0
# 128420     4.5             5  300.0     6                         0.0
#
#         cuisine_1_Afghani  cuisine_1_African  cuisine_1_American  \
# id
# 10540                 0.0                0.0                 0.0
# 279404                0.0                0.0                 0.0
# 234933                0.0                0.0                 0.0
# 30150                 0.0                0.0                 0.0
# 231590                0.0                0.0                 0.0
# 56318                 0.0                0.0                 0.0
# 146253                0.0                0.0                 0.0
# 480768                0.0                0.0                 0.0
# 503857                0.0                0.0                 0.0
# 128420                0.0                0.0                 0.0
#
#         cuisine_1_Andhra  cuisine_1_Arabian  ...  \
# id                                           ...
# 10540                0.0                0.0  ...
# 279404               0.0                0.0  ...
# 234933               0.0                0.0  ...
# 30150                0.0                0.0  ...
# 231590               0.0                0.0  ...
# 56318                0.0                0.0  ...
# 146253               0.0                0.0  ...
# 480768               0.0                0.0  ...
# 503857               0.0                0.0  ...
# 128420               0.0                0.0  ...
#
#         city_main_New BEL Road,Bangalore  city_main_Noida  city_main_Other  \
# id
# 10540                                0.0              0.0              0.0
# 279404                               0.0              0.0              0.0
# 234933                               0.0              0.0              0.0
# 30150                                0.0              0.0              0.0
# 231590                               0.0              0.0              0.0
# 56318                                0.0              0.0              0.0
# 146253                               0.0              0.0              0.0
# 480768                               0.0              0.0              0.0
# 503857                               0.0              0.0              0.0
# 128420                               0.0              0.0              0.0
#
#         city_main_Pune  city_main_Surat  city_main_Vadodara  \
# id
# 10540              0.0              0.0                 0.0
# 279404             0.0              0.0                 0.0
# 234933             0.0              0.0                 0.0
# 30150              0.0              0.0                 0.0
# 231590             0.0              0.0                 0.0
# 56318              0.0              0.0                 0.0
# 146253             0.0              0.0                 0.0
# 480768             0.0              0.0                 0.0
# 503857             0.0              0.0                 0.0
# 128420             0.0              0.0                 0.0
#
#         city_main_Vijayawada  city_main_Vizag  cluster  similarity_score
# id
# 10540                    0.0              0.0        5          0.999971
# 279404                   0.0              0.0        5          0.999971
# 234933                   0.0              0.0        5          0.999970
# 30150                    0.0              0.0        5          0.999970
# 231590                   0.0              0.0        5          0.999970
# 56318                    0.0              0.0        5          0.999970
# 146253                   0.0              0.0        5          0.999969
# 480768                   0.0              0.0        5          0.999968
# 503857                   0.0              0.0        5          0.999968
# 128420                   0.0              0.0        5          0.999968
#
# [10 rows x 267 columns]

# %%
cluster_df.sort_values(by='similarity_score', ascending=False ).to_csv('dataset/swiggy_recommendation_28112025.csv', index=True)

# %%
# loading the dataset
df_test = pd.read_csv('dataset/swiggy.csv')

# %%
recommendations_encoded = cluster_df.sort_values(by='similarity_score', ascending=False )

# %%
recommendations=df_test[df_test['id'].isin(recommendations_encoded.index)].copy()

# %%
recommendations["similarity_score"] = recommendations["id"].map(recommendations_encoded["similarity_score"])

# %%
# Final multi-column sort
recommendations = recommendations.sort_values(
    by=['similarity_score', "city"],
    ascending=[False, True]
)
recommendations.head(10)
# Out:
#            id                     name           city rating  rating_count  \
# 43224   10540        Murugan Idli Shop  Adyar,Chennai    4.1  500+ ratings
# 43437  279404            Noodle Doodle  Adyar,Chennai    3.8   50+ ratings
# 43345  234933                Wow! Momo  Adyar,Chennai    4.2  500+ ratings
# 43241   56318                 Munveedu  Adyar,Chennai    4.3  500+ ratings
# 43388  231590              Chinese Wox  Adyar,Chennai    4.3  500+ ratings
# 43403   30150        Adyar Sree Bhavan  Adyar,Chennai    4.3  500+ ratings
# 43253  146253                    Saldo  Adyar,Chennai    3.8   50+ ratings
# 43251  480768    Rolls & Bowls Company  Adyar,Chennai    4.0   50+ ratings
# 43231    5719   Prem's Graama Bhojanam  Adyar,Chennai    4.5  500+ ratings
# 43371  128420  Hotel Sri Lakshmi Sagar  Adyar,Chennai    4.5  500+ ratings
#
#         cost                    cuisine          lic_no  \
# 43224  ₹ 300               South Indian  12417000000000
# 43437  ₹ 250            Chinese,Tibetan  12414002003495
# 43345  ₹ 300       Tibetan,Healthy Food  12420002001411
# 43241  ₹ 300     South Indian,Chettinad  12421002001648
# 43388  ₹ 300                    Chinese         license
# 43403  ₹ 300  South Indian,North Indian  22419538000526
# 43253  ₹ 300        Continental,Tandoor         license
# 43251  ₹ 250       Chinese,North Indian  12422002000188
# 43231  ₹ 300               South Indian  12419002004124
# 43371  ₹ 300  North Indian,South Indian  12417002002943
#
#                                                     link  \
# 43224  https://www.swiggy.com/restaurants/murugan-idl...
# 43437  https://www.swiggy.com/restaurants/noodle-dood...
# 43345  https://www.swiggy.com/restaurants/wow-momo-ad...
# 43241  https://www.swiggy.com/restaurants/munveedu-ad...
# 43388  https://www.swiggy.com/restaurants/chinese-wox...
# 43403  https://www.swiggy.com/restaurants/adyar-sree-...
# 43253  https://www.swiggy.com/restaurants/saldo-kastu...
# 43251  https://www.swiggy.com/restaurants/rolls-and-b...
# 43231  https://www.swiggy.com/restaurants/prems-graam...
# 43371  https://www.swiggy.com/restaurants/hotel-sri-l...
#
#                                                  address              menu  \
# 43224  Murugan Idli Shop, E 149 6th Avenue, Near vala...   Menu/10540.json
# 43437  Noodle Doodle, No.7/3M, 4th Main Road, Basent ...  Menu/279404.json
# 43345  Wow! Momo, no 13/2, nehru nagar, 2nd main road...  Menu/234933.json
# 43241  Munveedu, 34/72A, 4th Main Road, Gandhi Nagar,...   Menu/56318.json
# 43388  Chinese Wox, 2/10, Gandhi Mandapam Road, Kottu...  Menu/231590.json
# 43403  Adyar Sree Bhavan, 138, Lattice Bridge Road, A...   Menu/30150.json
# 43253  Saldo, 7/12 , 8th Main Road , Ground Floor,kas...  Menu/146253.json
# 43251  Rolls & Bowls Company, Ground Floor, Door No- ...  Menu/480768.json
# 43231  Prem's Graama Bhojanam, 19/90, Sardar Patel Ro...    Menu/5719.json
# 43371  Hotel Sri Lakshmi Sagar, 177, LB Road, Kamaraj...  Menu/128420.json
#
#        similarity_score
# 43224          0.999971
# 43437          0.999971
# 43345          0.999970
# 43241          0.999970
# 43388          0.999970
# 43403          0.999970
# 43253          0.999969
# 43251          0.999968
# 43231          0.999968
# 43371          0.999968

# %%
pickle.dump(df_test, open('pickles/encoded_df.pkl', 'wb'))

# %%
recommendations
# Out:
#             id                              name                city rating  \
# 0       297700          Kumbakarna Biryani House               Adoni    3.3
# 1       128420           Hotel Sri Lakshmi Sagar       Adyar,Chennai    4.5
# 2       191366                  The Biryani Life       Adyar,Chennai    4.0
# 3       350553              Agra Biryani Hotspot                Agra    3.9
# 4       485620  Hotel VIP International Agartala            Agartala    2.7
# ...        ...                               ...                 ...    ...
# 148450  222071                M/S K/K Restaurant              Tezpur     --
# 148451  304862                      AAKASH FOODS      Tiruvannamalai     --
# 148452  384579          SHRI MAHAVIR GRUH UDHYOG  Vijay Nagar,Indore     --
# 148453  209433      The Nirvana Fast Food Centre          Jalpaiguri    4.0
# 148454  209434                       The Nirvana          Jalpaiguri    3.8
#
#            rating_count   cost                    cuisine          lic_no  \
# 0           50+ ratings  ₹ 250       Biryani,South Indian  20121022000134
# 1          500+ ratings  ₹ 300  North Indian,South Indian  12417002002943
# 2           20+ ratings  ₹ 250         Biryani,Hyderabadi  12419002000307
# 3           50+ ratings  ₹ 300             Biryani,Kebabs  22720590000200
# 4           50+ ratings  ₹ 300             Biryani,Kebabs  12521010000287
# ...                 ...    ...                        ...             ...
# 148450  Too Few Ratings    NaN             Indian,Chinese  20319113000233
# 148451  Too Few Ratings    NaN                     Indian  12418024000892
# 148452  Too Few Ratings    NaN                     Snacks  21421850003316
# 148453     100+ ratings    NaN             Indian,Chinese  22819009000721
# 148454     100+ ratings    NaN       North Indian,Chinese  12818009000291
#
#                                                      link  \
# 0       https://www.swiggy.com/restaurants/kumbakarna-...
# 1       https://www.swiggy.com/restaurants/hotel-sri-l...
# 2       https://www.swiggy.com/restaurants/the-biryani...
# 3       https://www.swiggy.com/restaurants/agra-biryan...
# 4       https://www.swiggy.com/restaurants/hotel-vip-i...
# ...                                                   ...
# 148450  https://www.swiggy.com/restaurants/m-s-k-k-res...
# 148451  https://www.swiggy.com/restaurants/aakash-food...
# 148452  https://www.swiggy.com/restaurants/shri-mahavi...
# 148453  https://www.swiggy.com/restaurants/the-nirvana...
# 148454  https://www.swiggy.com/restaurants/the-nirvana...
#
#                                                   address              menu  \
# 0       Kumbakarna Biryani House, Below Dwaraka comple...  Menu/297700.json
# 1       Hotel Sri Lakshmi Sagar, 177, LB Road, Kamaraj...  Menu/128420.json
# 2       The Biryani Life, 26/10, Kasthuribai Nagar, 3r...  Menu/191366.json
# 3       Agra Biryani Hotspot, S S272 SHAHEED NAGAR WAR...  Menu/350553.json
# 4       Hotel VIP International Agartala, Ujan Abhoyna...  Menu/485620.json
# ...                                                   ...               ...
# 148450        M/S K/K Restaurant, Near Mahabhairab Mandir  Menu/222071.json
# 148451  AAKASH FOODS, NO 7 , SRIRAM NAGAR,POLUR ROAD,T...  Menu/304862.json
# 148452  SHRI MAHAVIR GRUH UDHYOG, 102/584 NIRMAL REGEN...  Menu/384579.json
# 148453  The Nirvana Fast Food Centre, Merchant Rd, Jal...  Menu/209433.json
# 148454                       The Nirvana, old police line  Menu/209434.json
#
#         similarity_score
# 0               0.999975
# 1               0.999973
# 2               0.999968
# 3               0.999965
# 4               0.999964
# ...                  ...
# 148450          0.024137
# 148451          0.024133
# 148452          0.024128
# 148453          0.024128
# 148454          0.024121
#
# [148455 rows x 12 columns]

# %%
# Final recommendation

# ---------------------
# Load Pickled Files
# ---------------------

import numpy as np
from sklearn.metrics.pairwise import cosine_similarity


with open("pickles/city_area.pkl", "rb") as f:
    city_area_dict = pickle.load(f)

with open("pickles/cuisines.pkl", "rb") as f:
    cuisines_list = pickle.load(f)

with open("pickles/rating_counts.pkl", "rb") as f:
    rating_list = pickle.load(f)

with open("pickles/oneHot_cuisine.pkl", "rb") as f:
    encoder_cuisine = pickle.load(f)

with open("pickles/oneHot_city.pkl", "rb") as f:
    encoder_city = pickle.load(f)

with open("pickles/label_area.pkl", "rb") as f:
    label_area = pickle.load(f)

with open("pickles/encoder_rating_count.pkl", "rb") as f:
    encoder_rating_count = pickle.load(f)

with open("pickles/kmeans_model.pkl", "rb") as f:
    model = pickle.load(f)

with open("pickles/processed_df.pkl", "rb") as f:
    processed_df = pickle.load(f)

with open("pickles/encoded_df.pkl", "rb") as f:
    encoded_df = pickle.load(f)


def get_recommendations(city, area, cuisine, min_rating):
    # df = processed_df.copy()
    user_df = pd.DataFrame([{
        "rating": 3,
        "rating_count": min_rating,
        "cost": processed_df['cost'].median(),
        "area": area.lower(),
        "cuisine_1": cuisine,
        "cuisine_2": cuisine,
        "city_main": city
    }])
    # -------------------------
    # 2. Encode numeric + label encoded values
    # -------------------------
    enc_rating = np.array([[user_df['rating'].iloc[0]]])
    enc_cost = np.array([[user_df['cost'].iloc[0]]])
    enc_rating_count = encoder_rating_count.transform(
        user_df['rating_count']
    ).reshape(1, -1)
    # enc_area = label_area.transform(
    #     user_df['area']
    # ).reshape(1, -1)
    # ---- FIX: Normalize area before encoding ----
    user_area = user_df['area'].iloc[0].lower().strip()

    # Make label_encoder classes lowercase
    label_area.classes_ = np.array([c.lower() for c in label_area.classes_])

    # Now encode safely
    enc_area = label_area.transform([user_area]).reshape(1, -1)

    # -------------------------
    # 3. OneHot encodings
    # -------------------------
    enc_cuisine = encoder_cuisine.transform(
        user_df[['cuisine_1', 'cuisine_2']]
    )
    enc_city = encoder_city.transform(
        user_df[['city_main']]
    )

    # -------------------------
    # 4. Build FINAL VECTOR (Exact feature order used in training)
    # -------------------------
    final_vector = np.hstack([
        enc_rating,         # feature_rating
        enc_rating_count,   # feature_rating_count
        enc_cost,           # feature_cost
        enc_area,           # feature_area
        enc_cuisine,        # feature_cuisine_*
        enc_city            # feature_city_*
    ])

    # -------------------------
    # 5. Predict Cluster
    # -------------------------
    # cluster = model.predict(final_vector)[0]
    # cluster_df = encoded_df[encoded_df['cluster'] == cluster].copy()
    # cluster_vector = cluster_df.drop(columns=['cluster']).values
    # sim_scores = cosine_similarity(final_vector, cluster_vector)[0]
    # cluster_df["similarity_score"] = sim_scores

    cluster_df = encoded_df.copy()
    cluster_vector = encoded_df.drop(columns=['cluster']).values
    # print(encoded_df.drop(columns=['cluster']).columns)
    sim_scores = cosine_similarity(final_vector, cluster_vector)[0]
    cluster_df["similarity_score"] = sim_scores
    

    recommendations_encoded = cluster_df.sort_values(by='similarity_score', ascending=False )
    recommendations=processed_df[processed_df['id'].isin(recommendations_encoded.index)].copy()
    recommendations["similarity_score"] = recommendations["id"].map(recommendations_encoded["similarity_score"])
    recommendations = recommendations.sort_values(
        by=['similarity_score', "city_main"],
        ascending=[False, True]
    )
    
    # print(recommendations.head(10))
    return recommendations
    # return df

# %%
results = get_recommendations("Chennai", "adyar", "Biryani", "100+ ratings")

# %%
# results[results["city_main"] == "Chennai"]
results.head(10)
# Out:
#             id                              name  rating  rating_count   cost  \
# 43451   303976       Dindigul Velu Biryani Kadai     4.3  100+ ratings  300.0
# 579     387274                THE SERIAL GRILLER     3.5  100+ ratings  300.0
# 43303   487355                  Big Bowl Company     3.5  100+ ratings  250.0
# 111075  135332                       Anna Snacks     4.4  100+ ratings  400.0
# 111121   49651                    Domino's Pizza     4.4  100+ ratings  400.0
# 111063  207933                Chetak Sweet Point     4.3  100+ ratings  400.0
# 111308  328874  Charcoal Eats - Biryani & Beyond     4.4  100+ ratings  499.0
# 111169  303833      Priyanka pure veg restaurant     4.2  100+ ratings  400.0
# 111127  413980                               KFC     4.1  100+ ratings  400.0
# 111206   29445                         Sai Nidhi     4.1  100+ ratings  400.0
#
#                           cuisine          lic_no  \
# 43451              Biryani,Indian  12419002004733
# 579               Biryani,Chinese  22521050000391
# 43303        Chinese,North Indian  12422002000188
# 111075               South Indian  21521073000272
# 111121                     Pizzas  11513014003415
# 111063                     Indian  11519015000256
# 111308       Biryani,North Indian  11520015000289
# 111169                     Indian  11518015000347
# 111127            American,Snacks  11521015000210
# 111206  North Indian,South Indian  11518015000055
#
#                                                      link  \
# 43451   https://www.swiggy.com/restaurants/dindigul-ve...
# 579     https://www.swiggy.com/restaurants/the-serial-...
# 43303   https://www.swiggy.com/restaurants/big-bowl-co...
# 111075  https://www.swiggy.com/restaurants/anna-snacks...
# 111121  https://www.swiggy.com/restaurants/dominos-piz...
# 111063  https://www.swiggy.com/restaurants/chetak-swee...
# 111308  https://www.swiggy.com/restaurants/charcoal-ea...
# 111169  https://www.swiggy.com/restaurants/priyanka-pu...
# 111127  https://www.swiggy.com/restaurants/kfc-madhuri...
# 111206  https://www.swiggy.com/restaurants/sai-nidhi-a...
#
#                                                   address              menu  \
# 43451   Dindigul Velu Biryani Kadai, NO.163, SMS Build...  Menu/303976.json
# 579     THE SERIAL GRILLER, 3, Officers Quarter Ln, Kr...  Menu/387274.json
# 43303   Big Bowl Company, Ground Floor, Door No- 24/11...  Menu/487355.json
# 111075  Anna Snacks, Anna Snacks, 1, Rainbow Apartment...  Menu/135332.json
# 111121  Domino's Pizza, Surme Plaza, Mumbra, Thane Sho...   Menu/49651.json
# 111063  Chetak Sweet Point, Vraj vihar CHS Ltd Shop no...  Menu/207933.json
# 111308  Charcoal Eats - Biryani & Beyond, SHOP NO 2, D...  Menu/328874.json
# 111169  Priyanka pure veg restaurant, Priyanka Pure Ve...  Menu/303833.json
# 111127  KFC, Shop Nos. A10, A11, A13, A14 and A15, Gro...  Menu/413980.json
# 111206  Sai Nidhi, 105  Panchsheel Vishal Complex  1 S...   Menu/29445.json
#
#             area city_main     cuisine_1     cuisine_2  similarity_score
# 43451      Adyar   Chennai       Biryani        Indian          0.999975
# 579     Agartala     Other       Biryani       Chinese          0.999972
# 43303      Adyar   Chennai       Chinese  North Indian          0.999966
# 111075    Airoli    Mumbai  South Indian          None          0.999966
# 111121    Airoli    Mumbai        Pizzas          None          0.999966
# 111063    Airoli    Mumbai        Indian          None          0.999965
# 111308    Airoli    Mumbai       Biryani  North Indian          0.999965
# 111169    Airoli    Mumbai        Indian          None          0.999965
# 111127    Airoli    Mumbai      American        Snacks          0.999965
# 111206    Airoli    Mumbai  North Indian  South Indian          0.999965

# %%
# -----------------------
# TIERED PRIORITY SYSTEM
# -----------------------

def compute_priority(row):
    city = "chennai" 
    area = "adyar" 
    c1 = "Biryani"
    
    score = 0

    # Perfect match: area + cuisine + city
    if (row["area"] == area and 
        (row["cuisine_1"] == c1 or row["cuisine_2"] == c1) and 
        row["city_main"] == city):
        score += 4

    # City + Cuisine match
    elif ((row["cuisine_1"] == c1 or row["cuisine_2"] == c1) and 
           row["city_main"] == city):
        score += 3

    # Area + City match
    elif (row["area"] == area and row["city_main"] == city):
        score += 2

    # City-only match
    elif row["city_main"] == city:
        score += 1

    return score

results["priority"] = results.apply(compute_priority, axis=1)

# FINAL SORTING:
# results = results.sort_values(
#     by=["priority", "similarity_score"],
#     ascending=[False, False]
# )
results = results.sort_values(
    by=["priority"],
    ascending=[True]
)
# Out:
# 579       0
# 111075    0
# 111121    0
# 111063    0
# 111308    0
#          ..
# 24864     0
# 24867     0
# 24886     0
# 126375    0
# 88256     0
# Name: priority, Length: 40561, dtype: int64

# %%
results.head(10)
# Out:
#             id                              name  rating  rating_count   cost  \
# 579     387274                THE SERIAL GRILLER     3.5  100+ ratings  300.0
# 111075  135332                       Anna Snacks     4.4  100+ ratings  400.0
# 111121   49651                    Domino's Pizza     4.4  100+ ratings  400.0
# 111063  207933                Chetak Sweet Point     4.3  100+ ratings  400.0
# 111308  328874  Charcoal Eats - Biryani & Beyond     4.4  100+ ratings  499.0
# 111169  303833      Priyanka pure veg restaurant     4.2  100+ ratings  400.0
# 111127  413980                               KFC     4.1  100+ ratings  400.0
# 111206   29445                         Sai Nidhi     4.1  100+ ratings  400.0
# 111183  212537                  Oven Story Pizza     4.0  100+ ratings  400.0
# 111341  361270                           Wendy's     4.0  100+ ratings  400.0
#
#                           cuisine          lic_no  \
# 579               Biryani,Chinese  22521050000391
# 111075               South Indian  21521073000272
# 111121                     Pizzas  11513014003415
# 111063                     Indian  11519015000256
# 111308       Biryani,North Indian  11520015000289
# 111169                     Indian  11518015000347
# 111127            American,Snacks  11521015000210
# 111206  North Indian,South Indian  11518015000055
# 111183                     Pizzas  11519015000412
# 111341           American,Burgers  11519015000412
#
#                                                      link  \
# 579     https://www.swiggy.com/restaurants/the-serial-...
# 111075  https://www.swiggy.com/restaurants/anna-snacks...
# 111121  https://www.swiggy.com/restaurants/dominos-piz...
# 111063  https://www.swiggy.com/restaurants/chetak-swee...
# 111308  https://www.swiggy.com/restaurants/charcoal-ea...
# 111169  https://www.swiggy.com/restaurants/priyanka-pu...
# 111127  https://www.swiggy.com/restaurants/kfc-madhuri...
# 111206  https://www.swiggy.com/restaurants/sai-nidhi-a...
# 111183  https://www.swiggy.com/restaurants/oven-story-...
# 111341  https://www.swiggy.com/restaurants/wendys-sect...
#
#                                                   address              menu  \
# 579     THE SERIAL GRILLER, 3, Officers Quarter Ln, Kr...  Menu/387274.json
# 111075  Anna Snacks, Anna Snacks, 1, Rainbow Apartment...  Menu/135332.json
# 111121  Domino's Pizza, Surme Plaza, Mumbra, Thane Sho...   Menu/49651.json
# 111063  Chetak Sweet Point, Vraj vihar CHS Ltd Shop no...  Menu/207933.json
# 111308  Charcoal Eats - Biryani & Beyond, SHOP NO 2, D...  Menu/328874.json
# 111169  Priyanka pure veg restaurant, Priyanka Pure Ve...  Menu/303833.json
# 111127  KFC, Shop Nos. A10, A11, A13, A14 and A15, Gro...  Menu/413980.json
# 111206  Sai Nidhi, 105  Panchsheel Vishal Complex  1 S...   Menu/29445.json
# 111183  Oven Story Pizza, Shop No 15 and 16, Bhoskar B...  Menu/212537.json
# 111341  Wendy's, Shop No 15 and 16, Bhoskar Bhavan, Be...  Menu/361270.json
#
#             area city_main     cuisine_1     cuisine_2  similarity_score  \
# 579     Agartala     Other       Biryani       Chinese          0.999980
# 111075    Airoli    Mumbai  South Indian          None          0.999974
# 111121    Airoli    Mumbai        Pizzas          None          0.999974
# 111063    Airoli    Mumbai        Indian          None          0.999973
# 111308    Airoli    Mumbai       Biryani  North Indian          0.999973
# 111169    Airoli    Mumbai        Indian          None          0.999973
# 111127    Airoli    Mumbai      American        Snacks          0.999973
# 111206    Airoli    Mumbai  North Indian  South Indian          0.999973
# 111183    Airoli    Mumbai        Pizzas          None          0.999972
# 111341    Airoli    Mumbai      American       Burgers          0.999972
#
#         priority
# 579            0
# 111075         0
# 111121         0
# 111063         0
# 111308         0
# 111169         0
# 111127         0
# 111206         0
# 111183         0
# 111341         0
